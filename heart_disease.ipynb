# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.datasets import load_breast_cancer

# %%
url=C:\Users\KIIT\Videos\data sem 3\Python\DataSets\heart+disease.zip
# Out:
#   Cell In[13], line 1
#     url=C:\Users\KIIT\Videos\data sem 3\Python\DataSets\heart+disease.zip
#          ^
# SyntaxError: invalid syntax
