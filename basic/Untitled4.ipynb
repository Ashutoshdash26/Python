# %%
name="Ashutosh Dash"
print(name)
# Out:
# Ashutosh Dash

# %%
#commented
ashu={"game":"Cricket"}
print(ashu["game"])
print(type(ashu))
print(isinstance(ashu,dict))
# Out:
# Cricket
# <class 'dict'>
# True

# %%
age=float(2)
print(isinstance(age,int))
# Out:
# False

# %%
ab=int("20")
print(isinstance(ab,int))
print(3**3)
print(97//4)
# Out:
# True
# 27
# 24

# %%
k=int(98/9)
print(k)
l=98//9
print(l)
# Out:
# 10
# 10

# %%
print(int(-98/9))
print(-98//9)
# Out:
# -10
# -11

# %%
print("Minor" if age < 18 else "Adult")
# Out:
# Minor

# %%
n=28
print(age if n < 18 else k)
# Out:
# 10

# %%
print(True if age<18 else False)
# Out:
# True

# %%
name1="My name is "
name1+=name
print(name1)
# Out:
# My name is Ashutosh Dash

# %%
print("""
MY name is parth 

I am going to School
""")
# Out:
# MY name is parth
#
# I am going to School

# %%
gg="Ashutosh Dash"
print(gg.upper())
# Out:
# ASHUTOSH DASH

# %%
print("Ashutosh".upper())
# Out:
# ASHUTOSH

# %%
print("Ashutosh".lower())
print("ashutosh dash is a boy".title())
# Out:
# ashutosh
# Ashutosh Dash Is A Boy

# %%
print(name)
# Out:
# Ashutosh Dash

# %%
print(name.upper())
print(name.lower())
print(name.title())
print(name.islower())
print(name.isupper())
print(name.startswith("Ash"))
print(name.endswith("ash"))
print(name.replace("sh","as"))
print(name.split("Ash"))
print(name.strip())
print(name.join("nn"))
# Out:
# ASHUTOSH DASH
# ashutosh dash
# Ashutosh Dash
# False
# False
# True
# True
# Aasutoas Daas
# ['', 'utosh Dash']
# Ashutosh Dash
# nAshutosh Dashn

# %%
na= "     Ashutosh Dash  "
print(na.strip())
# Out:
# Ashutosh Dash

# %%
names = ["Ashu", "Ram", "Hari"]
print(", ".join(names))
# Out:
# Ashu, Ram, Hari

# %%
numbers = ["1","2","3"]
print(",".join(numbers))
print(name.find("sh"))
# Out:
# 1,2,3
# 1

# %%
print(name.isalpha())
print(name.isalnum())
print()
# Out:
# False
# False

# %%
nk="ash54das"
print(nk.isalnum())
# Out:
# True

# %%
print(name.isdecimal())
# Out:
# False

# %%
print(nk.isdecimal())
# Out:
# False

# %%
nn="54"
print(nn.isdecimal())
# Out:
# True

# %%
print(len(name))
print("Ashutosh\" dash")
print(name[1])
print(name[-1])
print(name[1:11])
# Out:
# 13
# Ashutosh" dash
# s
# h
# shutosh Da

# %%
book_1_read=True
book_2_read=False
read_any_book= any([book_1_read,book_2_read])
print(read_any_book)
read_any_book1= all([book_1_read,book_2_read])
print(read_any_book1)
# Out:
# True
# False

# %%
num1=2+3j
num2=complex(2,3)
print(num1)
print(num2.real,num2.imag)
print(num2,num1)
# Out:
# (2+3j)
# 2.0 3.0
# (2+3j) (2+3j)

# %%
print(abs(-5.5))
print(round(5.5))
# Out:
# 5.5
# 6
