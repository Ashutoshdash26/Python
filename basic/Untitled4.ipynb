# %%
name="Ashutosh Dash"
print(name)
# Out:
# Ashutosh Dash

# %%
#commented
ashu={"game":"Cricket"}
print(ashu["game"])
print(type(ashu))
print(isinstance(ashu,dict))
# Out:
# Cricket
# <class 'dict'>
# True

# %%
age=float(2)
print(isinstance(age,int))
# Out:
# False

# %%
ab=int("20")
print(isinstance(ab,int))
print(3**3)
print(97//4)
# Out:
# True
# 27
# 24

# %%
k=int(98/9)
print(k)
l=98//9
print(l)
# Out:
# 10
# 10

# %%
print(int(-98/9))
print(-98//9)
# Out:
# -10
# -11

# %%
print("Minor" if age < 18 else "Adult")
# Out:
# Minor

# %%
print(age if age < 18 else )
# Out:
# 2.0
