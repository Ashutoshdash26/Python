# %%
name="Ashutosh Dash"
print(name)
# Out:
# Ashutosh Dash

# %%
#commented
ashu={"game":"Cricket"}
print(ashu["game"])
print(type(ashu))
print(isinstance(ashu,dict))
# Out:
# Cricket
# <class 'dict'>
# True

# %%
age=float(2)
print(isinstance(age,int))
# Out:
# False

# %%
ab=int("20")
print(isinstance(ab,int))
print(3**3)
print(97//4)
# Out:
# True
# 27
# 24

# %%
k=int(98/9)
print(k)
k=98//9
print(k)
# Out:
# 10
# 10
