# %%
name="Ashutosh Dash"
print(name)
# Out:
# Ashutosh Dash

# %%
#commented
ashu={"game":"Cricket"}
print(ashu["game"])
print(type(ashu))
print(isinstance(ashu,dict))
# Out:
# Cricket
# <class 'dict'>
# True

# %%
age=2
print(isinstance(age,int))
# Out:
# True
