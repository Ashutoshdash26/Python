# %%
import random
def getChoice():
    choice=['rock', "paper", "Scissors"]
    player_choice=input("Enter rock,paper,scissor").upper()
    computer_choice=random.choice(choice)
    print(f"You played :  {player_choice}")
    choices={" Player: ":player_choice," Computer : ":computer_choice}
    return choices
    
g=getChoice()

dic={"name": "Ashutosh Dash", "colour":g}
print(dic)
# Out:
# Enter rock,paper,scissor rock
# You played :  ROCK
# {'name': 'Ashutosh Dash', 'colour': {' Player: ': 'ROCK  ', ' Computer : ': 'Scissors'}}

# %%
food=["Carrot","rice","Chicken"]
print(random.choice(food))
# Out:
# Chicken

# %%
def gg():
    choices={" Player: ":"player_choice"," Computer : ":"computer_choice"}
    return choices
ch=gg()
print(ch[" Player: "])
# Out:
# player_choice

# %%
def get():
    choice=['rock', "paper", "Scissors"]
    return choice
chh=get()
print(chh[2])
# Out:
# Scissors

# %%
print(1+1)
print("1"+"1")
print(type(chh))
print(type(ch))
print(type(1))
print(type('a'))
age=float(2)
print(isinstance(age,float))
agee=int(2.55)
print(isinstance(agee,int))
print(agee)
# Out:
# 2
# 11
# <class 'list'>
# <class 'dict'>
# <class 'int'>
# <class 'str'>
# True
# True
# 2

# %%
num=int("20")
numb=int("578")
print(isinstance(num,int))
print(num)
# Out:
# True
# 20

# %%
name="Ashu"
name+="tosh"
print(name)
# Out:
# Ashutosh
