# %%
import random
def getChoice():
    choice=['rock', "paper", "Scissors"]
    player_choice=input("Enter rock,paper,scissor").upper()
    computer_choice=random.choice(choice)
    print(f"You played :  {player_choice}")
    choices={" Player: ":player_choice," Computer : ":computer_choice}
    return choices
    
g=getChoice()

dic={"name": "Ashutosh Dash", "colour":g}
print(dic)
# Out:
# Enter rock,paper,scissor rock game
# You played :  ROCK GAME
# {'name': 'Ashutosh Dash', 'colour': {' Player: ': 'ROCK GAME', ' Computer : ': 'rock'}}

# %%
food=["Carrot","rice","Chicken"]
print(random.choice(food))
# Out:
# Chicken
