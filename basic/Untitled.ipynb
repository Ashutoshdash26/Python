# %%
import numpy as np

# %%
import pandas as pd

# %%
arr=np.array([[1,2,3],[4,5,6]])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
ar1=np.arange(5,20,3)
ar1
# Out:
# array([ 5,  8, 11, 14, 17])
