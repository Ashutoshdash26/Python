# %%
#sets
name={"Ashutosh ", "Parth ","Biswajeet "}
name1={"Ashutosh "}
print(name,name1)
# Out:
# {'Ashutosh ', 'Biswajeet ', 'Parth '} {'Ashutosh '}

# %%
intersect= name & name1
print(intersect)
# Out:
# {'Ashutosh '}

# %%
union=name |name1
print(union)
difference=name-name1
print(difference)
print(name<name1)
print(name>name1)
# Out:
# {'Ashutosh ', 'Biswajeet ', 'Parth '}
# {'Biswajeet ', 'Parth '}
# False
# True

# %%
print(list(name))
# Out:
# ['Ashutosh ', 'Biswajeet ', 'Parth ']

# %%
#Functions
def hello(name="My friend",age="22"):
    print(f"Hello {name} you are {age} year old")
na="ashutosh"
hello(na)
hello()
hello("mimi",78)
# Out:
# Hello ashutosh you are 22 year old
# Hello My friend you are 22 year old
# Hello mimi you are 78 year old

# %%
def change(valu):
    valu["name"]="Parth"
value={"name":"Ashutosh"}
change(value)
print(value)
# Out:
# {'name': 'Parth'}

# %%
def change(valu):
    valu=10
    return valu
va=9
va=change(va)
print(va)
# Out:
# 10

# %%
def game(gg):
    print(f"Hello {gg}")
    return f"{gg} is playing game","Footbal","Cricket"
ll=game("Ashutosh Dash ")
print(ll)
print(type(ll))
# Out:
# Hello Ashutosh Dash
# ('Ashutosh Dash  is playing game', 'Footbal', 'Cricket')
# <class 'tuple'>

# %%
a=9
def plus(a):
    a=a+1
plus(a)
print(a)
# Out:
# 9

# %%
def talk(gg):
    def sun(mg):
        print(mg)
    lines=gg.split()
    for i in lines:
        sun(i)
talk("I am going to bye the milk ")
# Out:
# I
# am
# going
# to
# bye
# the
# milk

# %%
def count():
    count=0
    def increment():
        nonlocal count
        count=count+1
        print(count)
    increment()    
    
count()
# Out:
# 1

# %%
def counter():
    count=0
    def increment():
        nonlocal count
        count=count+1
        return count
    return increment
increment=counter()
print(increment)
print(increment())
print(increment())
print(increment())
# Out:
# <function counter.<locals>.increment at 0x00000234F73DF400>
# 1
# 2
# 3

# %%
def counter():
    count=0
    def incr():
        nonlocal count
        count=count+1
        return count
    return incr
inc=counter()
print(inc)
print(inc())
print(inc())
print(inc())
# Out:
# <function counter.<locals>.incr at 0x0000023496747490>
# 1
# 2
# 3

# %%
def counter():
    count=0
    def incr():
        nonlocal count
        count=count+1
        return count
    return incr
#ini=counter()
print(ini)
print(ini())
print(ini())
print(ini())
# Out:
# <function counter.<locals>.incr at 0x00000234F6376560>
# 10
# 11
# 12
