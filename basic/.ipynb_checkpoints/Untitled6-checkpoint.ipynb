# %%
#sets
name={"Ashutosh ", "Parth ","Biswajeet "}
name1={"Ashutosh "}
print(name,name1)
# Out:
# {'Parth ', 'Ashutosh ', 'Biswajeet '} {'Ashutosh '}

# %%
intersect= name & name1
print(intersect)
# Out:
# {'Ashutosh '}

# %%
union=name |name1
print(union)
difference=name-name1
print(difference)
print(name<name1)
print(name>name1)
# Out:
# {'Parth ', 'Ashutosh ', 'Biswajeet '}
# {'Parth ', 'Biswajeet '}
# False
# True

# %%
print(list(name))
# Out:
# ['Parth ', 'Ashutosh ', 'Biswajeet ']

# %%
#Functions
def hello(name="My friend",age="22"):
    print(f"Hello {name} you are {age} year old")
na="ashutosh"
hello(na)
hello()
hello("mimi",78)
# Out:
# Hello ashutosh you are 22 year old
# Hello My friend you are 22 year old
# Hello mimi you are 78 year old

# %%
def change(valu):
    valu["name"]="Parth"
value={"name":"Ashutosh"}
change(value)
print(value)
# Out:
# {'name': 'Parth'}
