# %%
print(round(5.5,1))
# Out:
# 5.5

# %%
from enum import Enum
class state(Enum):
    INCATIVE=0
    ACTIVE=1
print(state.ACTIVE)
print(state.ACTIVE.value)
print(state(1))
print(state["ACTIVE"])
print(state["ACTIVE"].value)
print(state)
print(list(state))
print(len(state))
# Out:
# state.ACTIVE
# 1
# state.ACTIVE
# state.ACTIVE
# 1
# <enum 'state'>
# [<state.INCATIVE: 0>, <state.ACTIVE: 1>]
# 2

# %%
age=input("What is your age :")
print(f"Your age is {age}")
# Out:
# What is your age : 67
# Your age is 67

# %%
human=["Parth","mimi","biswajeet","Ashutosh"]
print(human)
# Out:
# ['Parth', 'mimi', 'biswajeet', 'Ashutosh']

# %%
print("Ashutosh" in human)
print("BAUE" in human)
print(human[-1])
# Out:
# True
# False
# Ashutosh

# %%
print(human[3:4])
print(human[:3])
print(human[2:])
print(human[:])
print(len(human))
# Out:
# ['Ashutosh']
# ['Parth', 'mimi', 'biswajeet']
# ['biswajeet', 'Ashutosh']
# ['Parth', 'mimi', 'biswajeet', 'Ashutosh']
# 4

# %%
human.append("monty")
print(human)
# Out:
# ['Parth', 'mimi', 'biswajeet', 'Ashutosh', 'monty']

# %%
human.extend(["abhinab",69,"subhashree","MS"])
print(human)
# Out:
# ['Parth', 'mimi', 'biswajeet', 'Ashutosh', 'monty', 'abhinab', 69, 'subhashree', 'MS']

# %%
human.remove(69)
print(human)
# Out:
# ['Parth', 'mimi', 'biswajeet', 'Ashutosh', 'monty', 'abhinab', 'subhashree', 'MS']

# %%
print(human.pop(3))
print(human.pop())
# Out:
# Ashutosh
# MS

# %%
print(human)
# Out:
# ['Parth', 'mimi', 'biswajeet', 'monty', 'abhinab', 'subhashree']

# %%
human.insert(2,"MS DHONI")
print(human)
# Out:
# ['Parth', 'mimi', 'MS DHONI', 'biswajeet', 'monty', 'abhinab', 'subhashree']

# %%
human[1:1]=["name1","name2"]
print(human)
# Out:
# ['Parth', 'name1', 'name2', 'mimi', 'MS DHONI', 'biswajeet', 'monty', 'abhinab', 'subhashree']

# %%
print(human.sort(key=str.lower))
print(human)
# Out:
# None
# ['abhinab', 'biswajeet', 'mimi', 'monty', 'MS DHONI', 'name1', 'name2', 'Parth', 'subhashree']

# %%
print(sorted(human,key=str.lower))
print(human)
# Out:
# ['abhinab', 'biswajeet', 'mimi', 'monty', 'MS DHONI', 'name1', 'name2', 'Parth', 'subhashree']
# ['Parth', 'name1', 'name2', 'mimi', 'MS DHONI', 'biswajeet', 'monty', 'abhinab', 'subhashree']

# %%
#Tuples
name=("Gold D Roger","Monky D Grape","Zoro","Sangi","Nami","Brook","a")
print(name[0])
print(name[-1])
print(name.index("Gold D Roger"))
print(len(name))
print("Gold D Roger" in name)
print(name[1:3])
print(sorted(name))
print(name)
newTuple=name+("Zimba","Monky D Luffy")
print(newTuple)
# Out:
# Gold D Roger
# a
# 0
# 7
# True
# ('Monky D Grape', 'Zoro')
# ['Brook', 'Gold D Roger', 'Monky D Grape', 'Nami', 'Sangi', 'Zoro', 'a']
# ('Gold D Roger', 'Monky D Grape', 'Zoro', 'Sangi', 'Nami', 'Brook', 'a')
# ('Gold D Roger', 'Monky D Grape', 'Zoro', 'Sangi', 'Nami', 'Brook', 'a', 'Zimba', 'Monky D Luffy')

# %%
#dictionaries
onepice={"name":"Gold D Roger", "Titel":"King of the pirate","place":"Loge "}
print(onepice)
print(onepice["name"])
onepice["place"]="Loge Town"
print(onepice)
onepice[2]="Loge Ton"
print(onepice)
print(onepice[2])
print(onepice.get("nae","King"))
print(onepice.pop(2))
print(onepice)
print(onepice.popitem())
print(onepice)
print("name" in onepice)
# Out:
# {'name': 'Gold D Roger', 'Titel': 'King of the pirate', 'place': 'Loge '}
# Gold D Roger
# {'name': 'Gold D Roger', 'Titel': 'King of the pirate', 'place': 'Loge Town'}
# {'name': 'Gold D Roger', 'Titel': 'King of the pirate', 'place': 'Loge Town', 2: 'Loge Ton'}
# Loge Ton
# King
# Loge Ton
# {'name': 'Gold D Roger', 'Titel': 'King of the pirate', 'place': 'Loge Town'}
# ('place', 'Loge Town')
# {'name': 'Gold D Roger', 'Titel': 'King of the pirate'}
# True

# %%
one={"luffy":"luffy","name":"Roger","name":"dd"}
print(one["luffy"])
print("dd" in one)
print(onepice.keys())
print(list(onepice.keys()))
print(onepice.values())
print(list(onepice.values()))
print(onepice.items())
print(list(onepice.items()))
onepice["Town"]="logetown"
print(onepice)
del onepice["Town"]
print(onepice)
two=onepice.copy()
print(two)
# Out:
# luffy
# False
# dict_keys(['name', 'Titel'])
# ['name', 'Titel']
# dict_values(['Gold D Roger', 'King of the pirate'])
# ['Gold D Roger', 'King of the pirate']
# dict_items([('name', 'Gold D Roger'), ('Titel', 'King of the pirate')])
# [('name', 'Gold D Roger'), ('Titel', 'King of the pirate')]
# {'name': 'Gold D Roger', 'Titel': 'King of the pirate', 'Town': 'logetown'}
# {'name': 'Gold D Roger', 'Titel': 'King of the pirate'}
# {'name': 'Gold D Roger', 'Titel': 'King of the pirate'}
