# %%
import numpy as np
import pandas as pd
df = pd.read_csv(r"C:\Users\Lab\Desktop\2470046_Amritanshu\Student Performance 1.csv")
df
# print("Data File:- \n\n",df)
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# 0         65.0           88.0           69.0             97.0
# 1         72.0           79.0           79.0             84.0
# 2         69.0           86.0           72.0             90.0
# 3         72.0           85.0           79.0             88.0
# 4         75.0            NaN            NaN              NaN
# 5         78.0           95.0           67.0             89.0
# 6          NaN           79.0           61.0            100.0
# 7         73.0           92.0           68.0             77.0
# 8         68.0            NaN           75.0             98.0
# 9         77.0           75.0           80.0            100.0
# 10         NaN           92.0            NaN              NaN
# 11        66.0           93.0           63.0             76.0
# 12        80.0           84.0           73.0             96.0
# 13        69.0           86.0           78.0             93.0
# ...

# %%
df.isnull()

# %%
df.notnull()

# %%
df.dropna()

# %%
df

# %%
df.dropna(inplace=True)

# %%
df

# %%
df1 = pd.read_csv(r"C:\Users\Lab\Desktop\2470046_Amritanshu\Student Performance 1.csv")
df1

# %%
#access single column

df1["Math_Score"]

# %%
df1["Math_Score"]=df1["Math_Score"].fillna(0)
df1["Reading_Score"]=df1["Reading_Score"].fillna(0)
df1["Writing_Score"]=df1["Writing_Score"].fillna(0)
df1["Placement_Score"]=df1["Placement_Score"].fillna(0)
df1

# %%
df1=df1.fillna(0)
df1

# %%
#copy df1 to df2
df2=df1
df2

# %%
df3=pd.read_csv(r"C:\Users\Lab\Desktop\2470046_Amritanshu\Student Performance 1.csv")
df3

# %%
df3=df3.fillna(0)
df3

# %%
x=df3["Math_Score"].mean()
print("mean = ",x)

# %%
df3["Math_Score"]

# %%
df3["Math_Score"]=df3["Math_Score"].fillna(x)
df3

# %%
df4=pd.read_csv(r"C:\Users\Lab\Desktop\2470046_Amritanshu\Student Performance 1.csv")
df4

# %%
=df4["Math_Score"].mean()
print(x)

# %%
df4["Math_Score"]=df4["Math_Score"].fillna(x)
df4

# %%
Med=df4["Reading_Score"].median()
print("Median :- ",Med)

# %%
df4["Reading_Score"]=df4["Reading_Score"].fillna(x)
df4

# %%
mo=df4["Writing_Score"].mode()
print("Mode :- ",mo)
print("Mode :- ",type(mo))

# %%
df4["Writing_Score"]=df4["Reading_Score"].fillna(mo)
df4

# %%
maxi=df4["Placement_Score"].max()
print("maximum :- ",maxi)

# %%
df4["Placement_Score"]=df4["Placement_Score"].fillna(maxi)
df4
